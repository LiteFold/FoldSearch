# %%
from searchapi import RCSBSearchAPI

client = RCSBSearchAPI()

# %%
client.structure_search(pdb_id="2PGH")
# Out:
# {'pdb_ids': ['2PGH',
#   '1QPW',
#   '1SDL',
#   '6KAR',
#   '1LJW',
#   '8PUR',
#   '6L5W',
#   '1O1I',
#   '1IBE',
#   '2MHB',
#   '1LFQ',
#   '4H2L',
#   '4MQC',
#   '1SDK',
#   '6HAL',
#   '8PUQ',
#   '4MQI',
#   '6SVA',
#   '5UCU',
#   '6KAQ',
#   '4N8T',
#   '1NS9',
#   '2ZLT',
#   '3HRW',
#   '1LFV',
#   '2D5X',
#   '3GOU',
#   '1LFT',
#   '4N7N',
#   '5C6E',
#   '6HK2',
#   '1R1X',
#   '1AJ9',
#   '6KAO',
#   '5E6E',
#   '2ZLW',
#   '6KAP',
#   '3D7O',
#   '1RVW',
#   '2HCO',
#   '3QJC',
#   '2HBD',
#   '1HHO',
#   '3B75',
#   '6L5V',
#   '1JY7',
#   '3P5Q',
#   '6KYE',
#   '2HBE',
#   '1G0B',
#   '1HCO',
#   '4MQG',
#   '4YU4',
#   '2HBF',
#   '2ZLU',
#   '2QU0',
#   '4N7P',
#   '4N7O',
#   '1S0H',
#   '4M4A',
#   '3S66',
#   '3QJB',
#   '8FDM',
#   '4M4B',
#   '1LFY',
#   '4MQH',
#   '4NI1',
#   '3EU1',
#   '1Y8K',
#   '1IWH',
#   '7AEV',
#   '3NL7',
#   '1YFF',
#   '5KER',
#   '1Y8I',
#   '7AEU',
#   '4MQK',
#   '7AET',
#   '7XGY',
#   '1HDS',
#   '3OO4',
#   '1T1N',
# ...
